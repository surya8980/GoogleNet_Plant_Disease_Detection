# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense,Flatten,Conv2D,MaxPooling2D
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers  import Concatenate
from tensorflow.keras.layers import AveragePooling2D, Dropout, Input, BatchNormalization, Flatten
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from PIL import Image
from tqdm import tqdm
import urllib
from tensorflow.keras.preprocessing import image
from sklearn.metrics import precision_recall_curve,roc_curve, auc
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
import os
from sklearn.metrics import log_loss, brier_score_loss
from sklearn.metrics import cohen_kappa_score
import matplotlib.cm as cm
from sklearn.metrics import matthews_corrcoef
import pandas as pd
import seaborn as sns
import numpy as np
import cv2
from sklearn.preprocessing import label_binarize
from sklearn.metrics import average_precision_score
from tensorflow.keras.utils import to_categorical
# %matplotlib inline
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
image_path="../input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/"

# %%
train_image_path="../input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/"
valid_image_path="../input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid/"
test_image_path="../input/new-plant-diseases-dataset/test/"

# %%
class_names = os.listdir(image_path)
print(class_names)
# Out:
# ['Tomato___Late_blight', 'Tomato___healthy', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Potato___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Tomato___Early_blight', 'Tomato___Septoria_leaf_spot', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Strawberry___Leaf_scorch', 'Peach___healthy', 'Apple___Apple_scab', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Bacterial_spot', 'Apple___Black_rot', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Peach___Bacterial_spot', 'Apple___Cedar_apple_rust', 'Tomato___Target_Spot', 'Pepper,_bell___healthy', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Potato___Late_blight', 'Tomato___Tomato_mosaic_virus', 'Strawberry___healthy', 'Apple___healthy', 'Grape___Black_rot', 'Potato___Early_blight', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Common_rust_', 'Grape___Esca_(Black_Measles)', 'Raspberry___healthy', 'Tomato___Leaf_Mold', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Pepper,_bell___Bacterial_spot', 'Corn_(maize)___healthy']

# %%
numberof_images={}
for class_name in class_names:
    numberof_images[class_name]=len(os.listdir(image_path+"/"+class_name))
images_each_class=pd.DataFrame(numberof_images.values(),index=numberof_images.keys(),columns=["Number of images"])
images_each_class
# Out:
#                                                     Number of images
# Tomato___Late_blight                                            1851
# Tomato___healthy                                                1926
# Grape___healthy                                                 1692
# Orange___Haunglongbing_(Citrus_greening)                        2010
# Soybean___healthy                                               2022
# Squash___Powdery_mildew                                         1736
# Potato___healthy                                                1824
# Corn_(maize)___Northern_Leaf_Blight                             1908
# Tomato___Early_blight                                           1920
# Tomato___Septoria_leaf_spot                                     1745
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot              1642
# Strawberry___Leaf_scorch                                        1774
# Peach___healthy                                                 1728
# Apple___Apple_scab                                              2016
# Tomato___Tomato_Yellow_Leaf_Curl_Virus                          1961
# Tomato___Bacterial_spot                                         1702
# Apple___Black_rot                                               1987
# Blueberry___healthy                                             1816
# Cherry_(including_sour)___Powdery_mildew                        1683
# Peach___Bacterial_spot                                          1838
# Apple___Cedar_apple_rust                                        1760
# Tomato___Target_Spot                                            1827
# Pepper,_bell___healthy                                          1988
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)                      1722
# Potato___Late_blight                                            1939
# Tomato___Tomato_mosaic_virus                                    1790
# Strawberry___healthy                                            1824
# Apple___healthy                                                 2008
# Grape___Black_rot                                               1888
# Potato___Early_blight                                           1939
# Cherry_(including_sour)___healthy                               1826
# Corn_(maize)___Common_rust_                                     1907
# Grape___Esca_(Black_Measles)                                    1920
# Raspberry___healthy                                             1781
# Tomato___Leaf_Mold                                              1882
# Tomato___Spider_mites Two-spotted_spider_mite                   1741
# Pepper,_bell___Bacterial_spot                                   1913
# Corn_(maize)___healthy                                          1859

# %%
batch_size=32

# %%
traindata_generator=tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,zoom_range=0.2,width_shift_range=0.2,height_shift_range=0.2,
                                                                    shear_range=0.2, horizontal_flip=True,validation_split=0.2)

validdata_generator=tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
testdata_generator=tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# %%
train_data_generator=traindata_generator.flow_from_directory(train_image_path,batch_size=batch_size,class_mode="categorical",
                                                           target_size=(120,120),color_mode="rgb",shuffle=True )
# Out:
# Found 70295 images belonging to 38 classes.

# %%
valid_data_generator=validdata_generator.flow_from_directory(train_image_path,batch_size=batch_size,class_mode="categorical",
                                                           target_size=(120,120),color_mode="rgb",shuffle=True )
# Out:
# Found 70295 images belonging to 38 classes.

# %%
test_data_generator=testdata_generator.flow_from_directory(valid_image_path,batch_size=batch_size,class_mode="categorical",
                                                           target_size=(120,120),color_mode="rgb",shuffle=False )
# Out:
# Found 17572 images belonging to 38 classes.

# %%
train_number=train_data_generator.samples
valid_number=valid_data_generator.samples

# %%
def inceptionnet(x,filters):
    
    #(1x1) layer
    layer1=Conv2D(filters=filters[0],kernel_size=(1,1),strides=1,padding="same",activation="relu")(x)
    
    #(3x3) layer
    layer2=Conv2D(filters=filters[1][0],kernel_size=(1,1),strides=1,padding="same",activation="relu")(x)
    

    layer2=Conv2D(filters=filters[1][1],kernel_size=(1,1),strides=1,padding="same",activation="relu")(layer2)
    
    #(5x5) layer
    
    layer3=Conv2D(filters=filters[2][0],kernel_size=(5,5),strides=1,padding="same",activation="relu")(x)
    
    layers=Conv2D(filters=filters[2][1],kernel_size=(5,5),strides=1,padding="same",activation="relu")(layer3)
    
    
    
    layer4=MaxPooling2D(pool_size=(3,3),strides=1,padding="same")(x)
    layer4=Conv2D(filters=filters[3],kernel_size=(1,1),strides=1,padding="same",activation="relu")(layer4)
    
    
    return Concatenate(axis=-1)([layer1,layer2,layer3,layer4])
    
    
def helperfunction(x,name=None):
    
    layer=AveragePooling2D(pool_size=(5,5),strides=3,padding="valid")(x)
    
    layer=Conv2D(filters=128,kernel_size=(1,1),strides=1,padding="same",activation="relu")(layer)
    
    layer=Flatten()(layer)
    
    layer=Dense(units=255,activation="relu")(layer)
    
    layer=Dropout(0.5)(layer)
    layer=Dense(units=38,activation="softmax",name=name)(layer)
    
    return layer
    
       
def googlenet():
    
    #taking layer input
    inputlayer=Input(shape=(120,120,3))
    
    #layer_1
    layer=Conv2D(filters=64,kernel_size=(7,7),strides=1,padding="same",activation="relu")(inputlayer)
    
    layer=MaxPooling2D(pool_size=(3,3),strides=2,padding="same")(layer)
    
    layer=BatchNormalization()(layer)
    
    #layer_2
    layer=Conv2D(filters=64,kernel_size=(1,1),strides=1,padding="same",activation="relu")(layer)
    
    layer=Conv2D(filters=192,kernel_size=(3,3),strides=1,padding="same",activation="relu")(layer)
    
    layer=BatchNormalization()(layer)
    layer=MaxPooling2D(pool_size=(3,3),strides=2,padding="same")(layer)
    
    #layer_3
    layer=inceptionnet(layer,[64,(96,128),(16,32),32])
    layer=inceptionnet(layer,[128,(128,192),(32,96),64])
    layer=MaxPooling2D(pool_size=(3,3),strides=2,padding="same")(layer)
    
    #layer_4
    layer=inceptionnet(layer,[192,(96,208),(16,48),64])
    final_0=helperfunction(layer,name="final_layer_0")
    
    layer=inceptionnet(layer,[160,(112,224),(24,64),64])
    layer=inceptionnet(layer,[128,(128,256),(24,64),64])
    layer=inceptionnet(layer,[112,(144,288),(32,64),64])
    final_1=helperfunction(layer,name="final_layer_1")
    
    layer=inceptionnet(layer,[256,(160,320),(32,128),128])
    layer=MaxPooling2D(pool_size=(3,3),strides=2,padding="same")(layer)
    
    
    #layer_5
    layer=inceptionnet(layer,[256,(160,320),(32,128),128])
    layer=inceptionnet(layer,[384,(192,384),(48,128),128])
    layer=AveragePooling2D(pool_size=(7,7),strides=1,padding="same")(layer)
    
    #layer_6
    
    layer=Flatten()(layer)
    layer=Dropout(0.5)(layer)
    layer=Dense(units=256,activation="linear")(layer)
    final_2=Dense(units=38,activation="softmax",name="final_layer_2")(layer)
    
    
    model=Model(inputs=inputlayer,outputs=[final_2,final_0,final_1])
    
    return model

# %%
model=googlenet()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 120, 120, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 120, 120, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 60, 60, 64)   0           ['conv2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 60, 60, 64)  256         ['max_pooling2d[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 60, 60, 64)   4160        ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 60, 60, 192)  110784      ['conv2d_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 60, 60, 192)  768        ['conv2d_2[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 30, 30, 192)  0          ['batch_normalization_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 30, 30, 96)   18528       ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 30, 30, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 30, 30, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 30, 30, 128)  12416       ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 30, 30, 16)   76816       ['max_pooling2d_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 30, 30, 32)   6176        ['max_pooling2d_2[0][0]']
#
#  concatenate (Concatenate)      (None, 30, 30, 240)  0           ['conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 30, 30, 128)  30848       ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 30, 30, 240)  0          ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 30, 30, 128)  30848       ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 30, 30, 192)  24768       ['conv2d_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 30, 30, 32)   192032      ['concatenate[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 30, 30, 64)   15424       ['max_pooling2d_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 30, 30, 416)  0           ['conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_12[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 15, 15, 416)  0          ['concatenate_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 15, 15, 96)   40032       ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 15, 15, 416)  0          ['max_pooling2d_4[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 15, 15, 192)  80064       ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 15, 15, 208)  20176       ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 15, 15, 16)   166416      ['max_pooling2d_4[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 15, 15, 64)   26688       ['max_pooling2d_5[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 15, 15, 480)  0           ['conv2d_15[0][0]',
#                                                                   'conv2d_17[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 15, 15, 112)  53872       ['concatenate_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 15, 15, 480)  0          ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 15, 15, 160)  76960       ['concatenate_2[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 15, 15, 224)  25312       ['conv2d_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 15, 15, 24)   288024      ['concatenate_2[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 15, 15, 64)   30784       ['max_pooling2d_6[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 15, 15, 472)  0           ['conv2d_22[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]',
#                                                                   'conv2d_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 15, 15, 128)  60544       ['concatenate_3[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 15, 15, 472)  0          ['concatenate_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 15, 15, 128)  60544       ['concatenate_3[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 15, 15, 256)  33024       ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 15, 15, 24)   283224      ['concatenate_3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 15, 15, 64)   30272       ['max_pooling2d_7[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 15, 15, 472)  0           ['conv2d_28[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_31[0][0]',
#                                                                   'conv2d_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 15, 15, 144)  68112       ['concatenate_4[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 15, 15, 472)  0          ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 15, 15, 112)  52976       ['concatenate_4[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 15, 15, 288)  41760       ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 15, 15, 32)   377632      ['concatenate_4[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 15, 15, 64)   30272       ['max_pooling2d_8[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 15, 15, 496)  0           ['conv2d_34[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_37[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 15, 15, 160)  79520       ['concatenate_5[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 15, 15, 496)  0          ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 15, 15, 256)  127232      ['concatenate_5[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 15, 15, 320)  51520       ['conv2d_42[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 15, 15, 32)   396832      ['concatenate_5[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 15, 15, 128)  63616       ['max_pooling2d_9[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 15, 15, 736)  0           ['conv2d_41[0][0]',
#                                                                   'conv2d_43[0][0]',
#                                                                   'conv2d_44[0][0]',
#                                                                   'conv2d_46[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 8, 8, 736)   0           ['concatenate_6[0][0]']
#  )
#
#  conv2d_48 (Conv2D)             (None, 8, 8, 160)    117920      ['max_pooling2d_10[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 8, 8, 736)   0           ['max_pooling2d_10[0][0]']
#  )
#
#  conv2d_47 (Conv2D)             (None, 8, 8, 256)    188672      ['max_pooling2d_10[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 8, 8, 320)    51520       ['conv2d_48[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 8, 8, 32)     588832      ['max_pooling2d_10[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 8, 8, 128)    94336       ['max_pooling2d_11[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 8, 8, 736)    0           ['conv2d_47[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'conv2d_50[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 8, 8, 192)    141504      ['concatenate_7[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 8, 8, 736)   0           ['concatenate_7[0][0]']
#  )
#
#  conv2d_53 (Conv2D)             (None, 8, 8, 384)    283008      ['concatenate_7[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 8, 8, 384)    74112       ['conv2d_54[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 8, 8, 48)     883248      ['concatenate_7[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 8, 8, 128)    94336       ['max_pooling2d_12[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 8, 8, 944)    0           ['conv2d_53[0][0]',
#                                                                   'conv2d_55[0][0]',
#                                                                   'conv2d_56[0][0]',
#                                                                   'conv2d_58[0][0]']
#
#  average_pooling2d (AveragePool  (None, 4, 4, 480)   0           ['concatenate_2[0][0]']
#  ing2D)
#
#  average_pooling2d_1 (AveragePo  (None, 4, 4, 496)   0           ['concatenate_5[0][0]']
#  oling2D)
#
#  average_pooling2d_2 (AveragePo  (None, 8, 8, 944)   0           ['concatenate_8[0][0]']
#  oling2D)
#
#  conv2d_21 (Conv2D)             (None, 4, 4, 128)    61568       ['average_pooling2d[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 4, 4, 128)    63616       ['average_pooling2d_1[0][0]']
#
#  flatten_2 (Flatten)            (None, 60416)        0           ['average_pooling2d_2[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['conv2d_21[0][0]']
#
#  flatten_1 (Flatten)            (None, 2048)         0           ['conv2d_40[0][0]']
#
#  dropout_2 (Dropout)            (None, 60416)        0           ['flatten_2[0][0]']
#
#  dense (Dense)                  (None, 255)          522495      ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 255)          522495      ['flatten_1[0][0]']
#
#  dense_2 (Dense)                (None, 256)          15466752    ['dropout_2[0][0]']
#
#  dropout (Dropout)              (None, 255)          0           ['dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 255)          0           ['dense_1[0][0]']
#
#  final_layer_2 (Dense)          (None, 38)           9766        ['dense_2[0][0]']
#
#  final_layer_0 (Dense)          (None, 38)           9728        ['dropout[0][0]']
#
#  final_layer_1 (Dense)          (None, 38)           9728        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 22,294,692
# Trainable params: 22,294,180
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
learning_rate = 0.001

opti = Adam(learning_rate=learning_rate)

model.compile(loss=['categorical_crossentropy', 'categorical_crossentropy', 'categorical_crossentropy'], loss_weights=[1, 0.3, 0.3], optimizer=opti, metrics=['accuracy'])

# %%
from tensorflow.keras import callbacks
early_stopping_cb = callbacks.EarlyStopping(monitor="val_loss", patience=3)
reduce_lr = callbacks.ReduceLROnPlateau(monitor="val_loss",  
                                              factor=0.2, 
                                              patience=2,
                                              verbose=1, 
                                              min_lr=1e-7)

checkpoint_path = "fine_tune_checkpoints/"
model_checkpoint = callbacks.ModelCheckpoint(checkpoint_path,
                                                      save_weights_only=True,
                                                      save_best_only=True,
                                                      monitor="val_loss")

history = model.fit(train_data_generator,
                    steps_per_epoch=train_number // batch_size,
                    epochs=30,
                    verbose=1,
                    callbacks=[early_stopping_cb, model_checkpoint, reduce_lr],
                    validation_data = valid_data_generator, 
                    validation_steps=valid_number // batch_size,
                    # steps_per_epoch = 20,
                    # validation_steps = 20
                    )
# Out:
# Epoch 1/30
# 2196/2196 [==============================] - 1023s 451ms/step - loss: 2.7851 - final_layer_2_loss: 1.7364 - final_layer_0_loss: 1.6601 - final_layer_1_loss: 1.8355 - final_layer_2_accuracy: 0.4884 - final_layer_0_accuracy: 0.5047 - final_layer_1_accuracy: 0.4544 - val_loss: 4.4037 - val_final_layer_2_loss: 2.6281 - val_final_layer_0_loss: 3.0363 - val_final_layer_1_loss: 2.8823 - val_final_layer_2_accuracy: 0.3986 - val_final_layer_0_accuracy: 0.4121 - val_final_layer_1_accuracy: 0.3968 - lr: 0.0010
# Epoch 2/30
# 2196/2196 [==============================] - 533s 243ms/step - loss: 1.0449 - final_layer_2_loss: 0.6235 - final_layer_0_loss: 0.6740 - final_layer_1_loss: 0.7306 - final_layer_2_accuracy: 0.8046 - final_layer_0_accuracy: 0.7903 - final_layer_1_accuracy: 0.7763 - val_loss: 1.6789 - val_final_layer_2_loss: 1.1031 - val_final_layer_0_loss: 0.9340 - val_final_layer_1_loss: 0.9853 - val_final_layer_2_accuracy: 0.6831 - val_final_layer_0_accuracy: 0.7274 - val_final_layer_1_accuracy: 0.7085 - lr: 0.0010
# Epoch 3/30
# 2196/2196 [==============================] - 530s 241ms/step - loss: 0.6812 - final_layer_2_loss: 0.4072 - final_layer_0_loss: 0.4461 - final_layer_1_loss: 0.4671 - final_layer_2_accuracy: 0.8736 - final_layer_0_accuracy: 0.8608 - final_layer_1_accuracy: 0.8564 - val_loss: 1.4660 - val_final_layer_2_loss: 0.8372 - val_final_layer_0_loss: 1.0744 - val_final_layer_1_loss: 1.0216 - val_final_layer_2_accuracy: 0.7649 - val_final_layer_0_accuracy: 0.7419 - val_final_layer_1_accuracy: 0.7530 - lr: 0.0010
# Epoch 4/30
# 2196/2196 [==============================] - 517s 235ms/step - loss: 0.5122 - final_layer_2_loss: 0.3083 - final_layer_0_loss: 0.3355 - final_layer_1_loss: 0.3442 - final_layer_2_accuracy: 0.9058 - final_layer_0_accuracy: 0.8956 - final_layer_1_accuracy: 0.8968 - val_loss: 1.8159 - val_final_layer_2_loss: 1.1737 - val_final_layer_0_loss: 1.1100 - val_final_layer_1_loss: 1.0307 - val_final_layer_2_accuracy: 0.7312 - val_final_layer_0_accuracy: 0.7556 - val_final_layer_1_accuracy: 0.7643 - lr: 0.0010
# Epoch 5/30
# 2196/2196 [==============================] - 522s 238ms/step - loss: 0.4498 - final_layer_2_loss: 0.2740 - final_layer_0_loss: 0.2937 - final_layer_1_loss: 0.2923 - final_layer_2_accuracy: 0.9182 - final_layer_0_accuracy: 0.9110 - final_layer_1_accuracy: 0.9134 - val_loss: 0.9638 - val_final_layer_2_loss: 0.5661 - val_final_layer_0_loss: 0.7459 - val_final_layer_1_loss: 0.5799 - val_final_layer_2_accuracy: 0.8277 - val_final_layer_0_accuracy: 0.7948 - val_final_layer_1_accuracy: 0.8275 - lr: 0.0010
# Epoch 6/30
# 2196/2196 [==============================] - 538s 245ms/step - loss: 0.3805 - final_layer_2_loss: 0.2319 - final_layer_0_loss: 0.2498 - final_layer_1_loss: 0.2454 - final_layer_2_accuracy: 0.9309 - final_layer_0_accuracy: 0.9246 - final_layer_1_accuracy: 0.9273 - val_loss: 0.7493 - val_final_layer_2_loss: 0.4561 - val_final_layer_0_loss: 0.4697 - val_final_layer_1_loss: 0.5076 - val_final_layer_2_accuracy: 0.8757 - val_final_layer_0_accuracy: 0.8727 - val_final_layer_1_accuracy: 0.8732 - lr: 0.0010
# Epoch 7/30
# 2196/2196 [==============================] - 510s 232ms/step - loss: 0.3584 - final_layer_2_loss: 0.2205 - final_layer_0_loss: 0.2316 - final_layer_1_loss: 0.2279 - final_layer_2_accuracy: 0.9351 - final_layer_0_accuracy: 0.9312 - final_layer_1_accuracy: 0.9341 - val_loss: 0.6822 - val_final_layer_2_loss: 0.4408 - val_final_layer_0_loss: 0.3311 - val_final_layer_1_loss: 0.4733 - val_final_layer_2_accuracy: 0.8731 - val_final_layer_0_accuracy: 0.9031 - val_final_layer_1_accuracy: 0.8706 - lr: 0.0010
# Epoch 8/30
# 2196/2196 [==============================] - 526s 240ms/step - loss: 0.3266 - final_layer_2_loss: 0.2007 - final_layer_0_loss: 0.2120 - final_layer_1_loss: 0.2078 - final_layer_2_accuracy: 0.9411 - final_layer_0_accuracy: 0.9364 - final_layer_1_accuracy: 0.9390 - val_loss: 0.8262 - val_final_layer_2_loss: 0.5031 - val_final_layer_0_loss: 0.5186 - val_final_layer_1_loss: 0.5585 - val_final_layer_2_accuracy: 0.8675 - val_final_layer_0_accuracy: 0.8666 - val_final_layer_1_accuracy: 0.8607 - lr: 0.0010
# Epoch 9/30
# 2196/2196 [==============================] - ETA: 0s - loss: 0.3017 - final_layer_2_loss: 0.1839 - final_layer_0_loss: 0.2022 - final_layer_1_loss: 0.1906 - final_layer_2_accuracy: 0.9473 - final_layer_0_accuracy: 0.9414 - final_layer_1_accuracy: 0.9449
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 2196/2196 [==============================] - 534s 243ms/step - loss: 0.3017 - final_layer_2_loss: 0.1839 - final_layer_0_loss: 0.2022 - final_layer_1_loss: 0.1906 - final_layer_2_accuracy: 0.9473 - final_layer_0_accuracy: 0.9414 - final_layer_1_accuracy: 0.9449 - val_loss: 1.0837 - val_final_layer_2_loss: 0.6559 - val_final_layer_0_loss: 0.7701 - val_final_layer_1_loss: 0.6562 - val_final_layer_2_accuracy: 0.8303 - val_final_layer_0_accuracy: 0.8207 - val_final_layer_1_accuracy: 0.8292 - lr: 0.0010
# Epoch 10/30
# 2196/2196 [==============================] - 517s 235ms/step - loss: 0.1043 - final_layer_2_loss: 0.0572 - final_layer_0_loss: 0.0848 - final_layer_1_loss: 0.0724 - final_layer_2_accuracy: 0.9815 - final_layer_0_accuracy: 0.9733 - final_layer_1_accuracy: 0.9779 - val_loss: 0.0653 - val_final_layer_2_loss: 0.0400 - val_final_layer_0_loss: 0.0426 - val_final_layer_1_loss: 0.0417 - val_final_layer_2_accuracy: 0.9873 - val_final_layer_0_accuracy: 0.9856 - val_final_layer_1_accuracy: 0.9866 - lr: 2.0000e-04
# Epoch 11/30
# 2196/2196 [==============================] - 509s 232ms/step - loss: 0.0847 - final_layer_2_loss: 0.0465 - final_layer_0_loss: 0.0689 - final_layer_1_loss: 0.0586 - final_layer_2_accuracy: 0.9855 - final_layer_0_accuracy: 0.9790 - final_layer_1_accuracy: 0.9820 - val_loss: 0.1418 - val_final_layer_2_loss: 0.0903 - val_final_layer_0_loss: 0.0932 - val_final_layer_1_loss: 0.0784 - val_final_layer_2_accuracy: 0.9775 - val_final_layer_0_accuracy: 0.9740 - val_final_layer_1_accuracy: 0.9786 - lr: 2.0000e-04
# Epoch 12/30
# 2196/2196 [==============================] - 532s 242ms/step - loss: 0.0789 - final_layer_2_loss: 0.0436 - final_layer_0_loss: 0.0633 - final_layer_1_loss: 0.0542 - final_layer_2_accuracy: 0.9862 - final_layer_0_accuracy: 0.9797 - final_layer_1_accuracy: 0.9832 - val_loss: 0.0455 - val_final_layer_2_loss: 0.0287 - val_final_layer_0_loss: 0.0285 - val_final_layer_1_loss: 0.0273 - val_final_layer_2_accuracy: 0.9911 - val_final_layer_0_accuracy: 0.9908 - val_final_layer_1_accuracy: 0.9917 - lr: 2.0000e-04
# Epoch 13/30
# 2196/2196 [==============================] - 514s 234ms/step - loss: 0.0717 - final_layer_2_loss: 0.0396 - final_layer_0_loss: 0.0588 - final_layer_1_loss: 0.0482 - final_layer_2_accuracy: 0.9879 - final_layer_0_accuracy: 0.9822 - final_layer_1_accuracy: 0.9852 - val_loss: 0.1879 - val_final_layer_2_loss: 0.1139 - val_final_layer_0_loss: 0.1309 - val_final_layer_1_loss: 0.1157 - val_final_layer_2_accuracy: 0.9684 - val_final_layer_0_accuracy: 0.9635 - val_final_layer_1_accuracy: 0.9669 - lr: 2.0000e-04
# Epoch 14/30
# 2196/2196 [==============================] - 532s 242ms/step - loss: 0.0664 - final_layer_2_loss: 0.0365 - final_layer_0_loss: 0.0531 - final_layer_1_loss: 0.0468 - final_layer_2_accuracy: 0.9886 - final_layer_0_accuracy: 0.9833 - final_layer_1_accuracy: 0.9857 - val_loss: 0.0420 - val_final_layer_2_loss: 0.0255 - val_final_layer_0_loss: 0.0305 - val_final_layer_1_loss: 0.0246 - val_final_layer_2_accuracy: 0.9918 - val_final_layer_0_accuracy: 0.9899 - val_final_layer_1_accuracy: 0.9917 - lr: 2.0000e-04
# Epoch 15/30
# 2196/2196 [==============================] - 506s 230ms/step - loss: 0.0609 - final_layer_2_loss: 0.0338 - final_layer_0_loss: 0.0486 - final_layer_1_loss: 0.0418 - final_layer_2_accuracy: 0.9896 - final_layer_0_accuracy: 0.9849 - final_layer_1_accuracy: 0.9871 - val_loss: 0.0569 - val_final_layer_2_loss: 0.0307 - val_final_layer_0_loss: 0.0474 - val_final_layer_1_loss: 0.0397 - val_final_layer_2_accuracy: 0.9903 - val_final_layer_0_accuracy: 0.9860 - val_final_layer_1_accuracy: 0.9884 - lr: 2.0000e-04
# Epoch 16/30
# 2196/2196 [==============================] - ETA: 0s - loss: 0.0616 - final_layer_2_loss: 0.0337 - final_layer_0_loss: 0.0504 - final_layer_1_loss: 0.0424 - final_layer_2_accuracy: 0.9891 - final_layer_0_accuracy: 0.9847 - final_layer_1_accuracy: 0.9870
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 2196/2196 [==============================] - 546s 249ms/step - loss: 0.0616 - final_layer_2_loss: 0.0337 - final_layer_0_loss: 0.0504 - final_layer_1_loss: 0.0424 - final_layer_2_accuracy: 0.9891 - final_layer_0_accuracy: 0.9847 - final_layer_1_accuracy: 0.9870 - val_loss: 0.0984 - val_final_layer_2_loss: 0.0528 - val_final_layer_0_loss: 0.0840 - val_final_layer_1_loss: 0.0679 - val_final_layer_2_accuracy: 0.9844 - val_final_layer_0_accuracy: 0.9780 - val_final_layer_1_accuracy: 0.9817 - lr: 2.0000e-04
# Epoch 17/30
# 2196/2196 [==============================] - 530s 241ms/step - loss: 0.0363 - final_layer_2_loss: 0.0183 - final_layer_0_loss: 0.0346 - final_layer_1_loss: 0.0255 - final_layer_2_accuracy: 0.9943 - final_layer_0_accuracy: 0.9891 - final_layer_1_accuracy: 0.9920 - val_loss: 0.0262 - val_final_layer_2_loss: 0.0147 - val_final_layer_0_loss: 0.0210 - val_final_layer_1_loss: 0.0175 - val_final_layer_2_accuracy: 0.9950 - val_final_layer_0_accuracy: 0.9928 - val_final_layer_1_accuracy: 0.9939 - lr: 4.0000e-05
# Epoch 18/30
# 2196/2196 [==============================] - 500s 228ms/step - loss: 0.0328 - final_layer_2_loss: 0.0163 - final_layer_0_loss: 0.0309 - final_layer_1_loss: 0.0240 - final_layer_2_accuracy: 0.9948 - final_layer_0_accuracy: 0.9895 - final_layer_1_accuracy: 0.9924 - val_loss: 0.0251 - val_final_layer_2_loss: 0.0132 - val_final_layer_0_loss: 0.0226 - val_final_layer_1_loss: 0.0169 - val_final_layer_2_accuracy: 0.9958 - val_final_layer_0_accuracy: 0.9931 - val_final_layer_1_accuracy: 0.9949 - lr: 4.0000e-05
# Epoch 19/30
# 2196/2196 [==============================] - 526s 240ms/step - loss: 0.0311 - final_layer_2_loss: 0.0154 - final_layer_0_loss: 0.0298 - final_layer_1_loss: 0.0227 - final_layer_2_accuracy: 0.9949 - final_layer_0_accuracy: 0.9907 - final_layer_1_accuracy: 0.9928 - val_loss: 0.0403 - val_final_layer_2_loss: 0.0229 - val_final_layer_0_loss: 0.0321 - val_final_layer_1_loss: 0.0257 - val_final_layer_2_accuracy: 0.9932 - val_final_layer_0_accuracy: 0.9906 - val_final_layer_1_accuracy: 0.9921 - lr: 4.0000e-05
# Epoch 20/30
# 2196/2196 [==============================] - ETA: 0s - loss: 0.0281 - final_layer_2_loss: 0.0135 - final_layer_0_loss: 0.0280 - final_layer_1_loss: 0.0207 - final_layer_2_accuracy: 0.9957 - final_layer_0_accuracy: 0.9910 - final_layer_1_accuracy: 0.9935
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 2196/2196 [==============================] - 504s 230ms/step - loss: 0.0281 - final_layer_2_loss: 0.0135 - final_layer_0_loss: 0.0280 - final_layer_1_loss: 0.0207 - final_layer_2_accuracy: 0.9957 - final_layer_0_accuracy: 0.9910 - final_layer_1_accuracy: 0.9935 - val_loss: 0.0277 - val_final_layer_2_loss: 0.0150 - val_final_layer_0_loss: 0.0226 - val_final_layer_1_loss: 0.0199 - val_final_layer_2_accuracy: 0.9951 - val_final_layer_0_accuracy: 0.9928 - val_final_layer_1_accuracy: 0.9941 - lr: 4.0000e-05
# Epoch 21/30
# 2196/2196 [==============================] - 514s 234ms/step - loss: 0.0272 - final_layer_2_loss: 0.0130 - final_layer_0_loss: 0.0273 - final_layer_1_loss: 0.0198 - final_layer_2_accuracy: 0.9958 - final_layer_0_accuracy: 0.9908 - final_layer_1_accuracy: 0.9936 - val_loss: 0.0269 - val_final_layer_2_loss: 0.0143 - val_final_layer_0_loss: 0.0236 - val_final_layer_1_loss: 0.0182 - val_final_layer_2_accuracy: 0.9954 - val_final_layer_0_accuracy: 0.9928 - val_final_layer_1_accuracy: 0.9944 - lr: 8.0000e-06

# %%
model.save("model.h5")
from tensorflow.keras.models import load_model

model = load_model("model.h5")

# %%
# Plotting
hist = history.history
def show_plt(type):
    if type == 1:
        plt.plot(hist["final_layer_2_accuracy"], label="accuracy")
        plt.plot(hist["val_final_layer_2_accuracy"], label="val_accuracy")
        plt.ylabel("Accuracy")
        plt.xlabel("Epochs #")
        plt.legend()
        plt.show()
    else:
        plt.plot(hist["loss"], label="loss")
        plt.plot(hist["val_final_layer_2_loss"], label="val_loss")
        plt.ylabel("Loss")
        plt.xlabel("Epochs #")
        plt.legend()
        plt.show()
        
show_plt(1)
show_plt(0)

# %%
pred, _, _=model.predict(test_data_generator)
final_predict = np.argmax(pred,axis=1)
true_data=test_data_generator.classes
# Out:
# 550/550 [==============================] - 115s 209ms/step

# %%
acc_score = accuracy_score(true_data,final_predict)
print(f'Accuracy Score: {acc_score:.4f}')
# Out:
# Accuracy Score: 0.9910

# %%
plt.figure(figsize=(40,40))
confusion = confusion_matrix(true_data, final_predict)
sns.heatmap(confusion, annot=True, fmt='d', cmap='jet',xticklabels=class_names,
            yticklabels=class_names,lw=6)
plt.xlabel('Predicted',fontsize=20,color="black")
plt.ylabel('True',fontsize=20,color="black")
plt.title('Confusion Matrix\n',fontsize=20,color="black")
plt.show()

# %%
print(classification_report(true_data, final_predict,target_names=class_names))
# Out:
#                                                     precision    recall  f1-score   support
#
#                               Tomato___Late_blight       1.00      1.00      1.00       504
#                                   Tomato___healthy       1.00      1.00      1.00       497
#                                    Grape___healthy       1.00      0.99      0.99       440
#           Orange___Haunglongbing_(Citrus_greening)       0.99      1.00      0.99       502
#                                  Soybean___healthy       0.99      0.98      0.99       454
#                            Squash___Powdery_mildew       1.00      1.00      1.00       421
#                                   Potato___healthy       0.99      1.00      0.99       456
#                Corn_(maize)___Northern_Leaf_Blight       0.96      0.99      0.97       410
#                              Tomato___Early_blight       1.00      1.00      1.00       477
#                        Tomato___Septoria_leaf_spot       1.00      0.96      0.98       477
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       1.00      1.00      1.00       465
#                           Strawberry___Leaf_scorch       1.00      0.97      0.98       472
#                                    Peach___healthy       0.97      1.00      0.99       480
#                                 Apple___Apple_scab       0.99      1.00      1.00       430
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       1.00      1.00      1.00       423
#                            Tomato___Bacterial_spot       1.00      0.99      1.00       503
#                                  Apple___Black_rot       1.00      0.98      0.99       459
#                                Blueberry___healthy       1.00      1.00      1.00       432
#           Cherry_(including_sour)___Powdery_mildew       1.00      1.00      1.00       478
#                             Peach___Bacterial_spot       1.00      0.97      0.98       497
#                           Apple___Cedar_apple_rust       1.00      1.00      1.00       485
#                               Tomato___Target_Spot       1.00      0.99      0.99       485
#                             Pepper,_bell___healthy       0.98      0.99      0.99       456
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       0.99      0.99      0.99       445
#                               Potato___Late_blight       0.99      0.99      0.99       505
#                       Tomato___Tomato_mosaic_virus       1.00      1.00      1.00       434
#                               Strawberry___healthy       1.00      1.00      1.00       444
#                                    Apple___healthy       1.00      1.00      1.00       456
#                                  Grape___Black_rot       0.99      0.99      0.99       425
#                              Potato___Early_blight       0.99      0.99      0.99       480
#                  Cherry_(including_sour)___healthy       0.99      0.98      0.99       463
#                        Corn_(maize)___Common_rust_       1.00      1.00      1.00       470
#                       Grape___Esca_(Black_Measles)       0.99      1.00      0.99       436
#                                Raspberry___healthy       0.97      0.97      0.97       435
#                                 Tomato___Leaf_Mold       0.97      0.93      0.95       457
#      Tomato___Spider_mites Two-spotted_spider_mite       1.00      1.00      1.00       490
#                      Pepper,_bell___Bacterial_spot       1.00      1.00      1.00       448
#                             Corn_(maize)___healthy       0.95      1.00      0.97       481
#
#                                           accuracy                           0.99     17572
#                                          macro avg       0.99      0.99      0.99     17572
#                                       weighted avg       0.99      0.99      0.99     17572

# %%
plt.figure(figsize=(5, 5))

img_url = "https://cdn.britannica.com/89/126689-004-D622CD2F/Potato-leaf-blight.jpg"

filename, headers = urllib.request.urlretrieve(img_url)
img_path = os.path.join(os.getcwd(), filename)
img = Image.open(img_path)
img = img.resize((120, 120))
img = np.array(img) / 255.0
img = np.expand_dims(img, axis=0)
probs = model.predict(img)[0]

# Get the predicted class index and name
pred_class_prob = np.argmax(probs)
pred_class_name = class_names[pred_class_prob]

max_prob = np.max(probs)
print(f'Predicted class: {pred_class_name}')
print(f'Maximum probability: {max_prob}')

# Display the image with the predicted class and probability
plt.imshow(img[0])
plt.axis('off')
plt.text(5, 15, f'Predicted class: {pred_class_name}\nMaximum probability: {max_prob:.2f}', fontsize=10, color='red', bbox=dict(facecolor='white', alpha=0.8))
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted class: Strawberry___healthy
# Maximum probability: 0.9813423752784729

# %%
plt.figure(figsize=(5, 5))

img_path = "/kaggle/input/new-plant-diseases-dataset/test/test/TomatoEarlyBlight2.JPG"

img = Image.open(img_path)
img = img.resize((120, 120))
img = np.array(img) / 255.0
img = np.expand_dims(img, axis=0)
probs = model.predict(img)[0]

# Get the predicted class index and name
pred_class_prob = np.argmax(probs)
pred_class_name = class_names[pred_class_prob]

max_prob = np.max(probs)
print(f'Predicted class: {pred_class_name}')
print(f'Maximum probability: {max_prob}')

# Display the image with the predicted class and probability
plt.imshow(img[0])
plt.axis('off')
plt.text(5, 15, f'Predicted class: {pred_class_name}\nMaximum probability: {max_prob:.2f}', fontsize=10, color='red', bbox=dict(facecolor='white', alpha=0.8))
plt.show()
# Out:
# 1/1 [==============================] - 0s 24ms/step
# Predicted class: Potato___Early_blight
# Maximum probability: 0.9999997615814209

# %%
plt.figure(figsize=(5, 5))

img_path = "/kaggle/input/new-plant-diseases-dataset/test/test/TomatoYellowCurlVirus4.JPG"

img = Image.open(img_path)
img = img.resize((120, 120))
img = np.array(img) / 255.0
img = np.expand_dims(img, axis=0)
probs = model.predict(img)[0]

# Get the predicted class index and name
pred_class_prob = np.argmax(probs)
pred_class_name = class_names[pred_class_prob]

max_prob = np.max(probs)
print(f'Predicted class: {pred_class_name}')
print(f'Maximum probability: {max_prob}')

# Display the image with the predicted class and probability
plt.imshow(img[0])
plt.axis('off')
plt.text(5, 15, f'Predicted class: {pred_class_name}\nMaximum probability: {max_prob:.2f}', fontsize=10, color='red', bbox=dict(facecolor='white', alpha=0.8))
plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Predicted class: Tomato___Spider_mites Two-spotted_spider_mite
# Maximum probability: 1.0

# %%
plt.figure(figsize=(5, 5))

img_path = "/kaggle/input/new-plant-diseases-dataset/test/test/AppleCedarRust2.JPG"

img = Image.open(img_path)
img = img.resize((120, 120))
img = np.array(img) / 255.0
img = np.expand_dims(img, axis=0)
probs = model.predict(img)[0]

# Get the predicted class index and name
pred_class_prob = np.argmax(probs)
pred_class_name = class_names[pred_class_prob]

max_prob = np.max(probs)
print(f'Predicted class: {pred_class_name}')
print(f'Maximum probability: {max_prob}')

# Display the image with the predicted class and probability
plt.imshow(img[0])
plt.axis('off')
plt.text(5, 15, f'Predicted class: {pred_class_name}\nMaximum probability: {max_prob:.2f}', fontsize=10, color='red', bbox=dict(facecolor='white', alpha=0.8))
plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Predicted class: Grape___healthy
# Maximum probability: 0.9999998807907104

# %%
plt.figure(figsize=(5, 5))

img_path = "/kaggle/input/new-plant-diseases-dataset/test/test/AppleScab3.JPG"
img = Image.open(img_path)
img = img.resize((120, 120))
img = np.array(img) / 255.0
img = np.expand_dims(img, axis=0)
probs = model.predict(img)[0]

# Get the predicted class index and name
pred_class_prob = np.argmax(probs)
pred_class_name = class_names[pred_class_prob]

max_prob = np.max(probs)
print(f'Predicted class: {pred_class_name}')
print(f'Maximum probability: {max_prob}')

# Display the image with the predicted class and probability
plt.imshow(img[0])
plt.axis('off')
plt.text(5, 15, f'Predicted class: {pred_class_name}\nMaximum probability: {max_prob:.2f}', fontsize=10, color='red', bbox=dict(facecolor='white', alpha=0.8))
plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Predicted class: Tomato___Late_blight
# Maximum probability: 1.0

# %%
plt.figure(figsize=(5, 5))

img_path = "/kaggle/input/new-plant-diseases-dataset/test/test/TomatoYellowCurlVirus2.JPG"

img = Image.open(img_path)
img = img.resize((120, 120))
img = np.array(img) / 255.0
img = np.expand_dims(img, axis=0)
probs = model.predict(img)[0]

# Get the predicted class index and name
pred_class_prob = np.argmax(probs)
pred_class_name = class_names[pred_class_prob]

max_prob = np.max(probs)
print(f'Predicted class: {pred_class_name}')
print(f'Maximum probability: {max_prob}')

# Display the image with the predicted class and probability
plt.imshow(img[0])
plt.axis('off')
plt.text(5, 15, f'Predicted class: {pred_class_name}\nMaximum probability: {max_prob:.2f}', fontsize=10, color='red', bbox=dict(facecolor='white', alpha=0.8))
plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Predicted class: Tomato___Spider_mites Two-spotted_spider_mite
# Maximum probability: 1.0
